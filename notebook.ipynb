# %% [markdown]
# ### Analyse CSV

# %%
import pandas as pd
import missingno as msno

df = pd.read_csv("data/data.csv")
print(df.describe)

# %matplotlib inline
msno.matrix(df.sample(250))


# Remove row with na value 
df_filtered = df.dropna()
print(df_filtered.describe)
# Out:
# <bound method NDFrame.describe of       age  taille  poids  revenu_estime_mois  historique_credits  \
# 0      73   161.1   67.3                 857                 NaN
# 1      44   168.2   74.9                5245                 2.0
# 2      71   160.3   45.5                3792                 0.0
# 3      62   161.9   87.7                3291                 NaN
# 4      18   178.0   77.6                3893                 NaN
# ...   ...     ...    ...                 ...                 ...
# 9995   37   163.6   96.7                3894                 1.0
# 9996   19   157.2   55.3                2969                 0.0
# 9997   71   163.0   77.2                2893                 NaN
# 9998   54   165.7   73.2                1193                 NaN
# 9999   54   173.9   77.8                 500                 NaN
#
#       risque_personnel  score_credit  loyer_mensuel  montant_pret
# 0                 0.11         615.0        1377.97  13157.101646
# 1                 0.79           NaN       10000.00  32408.309272
# 2                 0.13           NaN        5000.00  17975.461375
# 3                 0.32           NaN       10000.00  16004.737731
# 4                 0.66           NaN            NaN  10437.682760
# ...                ...           ...            ...           ...
# 9995              0.63           NaN        5000.00    500.000000
# 9996              0.37           NaN         787.63   7671.982681
# 9997              0.56           NaN        1184.94    500.000000
# 9998              0.87           NaN            NaN    500.000000
# 9999              0.70           NaN       10000.00   8162.127775
#
# [10000 rows x 9 columns]>
# <bound method NDFrame.describe of       age  taille  poids  revenu_estime_mois  historique_credits  \
# 6      22   170.8   60.9                 714                 0.0
# 9      28   161.6   81.2                 500                 2.0
# 13     53   158.2   84.3                 885                 3.0
# 14     57   158.9   57.3                3114                 4.0
# 16     45   188.0   87.6                1840                 2.0
# ...   ...     ...    ...                 ...                 ...
# 9948   27   174.4   48.5                 513                 1.0
# 9951   42   177.5   71.8                 500                 2.0
# 9952   66   162.2   56.9                1188                 2.0
# 9955   64   160.0   61.7                1515                 3.0
# 9970   35   163.9   56.7                1671                 2.0
#
#       risque_personnel  score_credit  loyer_mensuel  montant_pret
# 6                 0.46         772.0         699.57    500.000000
# 9                 0.66         356.0       10000.00    500.000000
# 13                0.48         375.0        5000.00  12373.560235
# 14                0.50         646.0       10000.00  20050.690686
# 16                0.52         434.0         596.00    500.000000
# ...                ...           ...            ...           ...
# 9948              0.93         583.0        5000.00    500.000000
# 9951              0.69         440.0       10000.00    500.000000
# 9952              0.18         692.0       10000.00    500.000000
# 9955              0.29         484.0         595.77   4323.341368
# 9970              0.41         581.0        1234.03    500.000000
#
# [1554 rows x 9 columns]>

# %% [markdown]
# This method is not correct cause 8500 lines has been removed. We need more data to train our model

# %% [markdown]
# ### FILTER AND REPLACE VALUE

# %%
# %run modules/filter_data.py
# Out:
# <bound method NDFrame.describe of       age  taille  poids  revenu_estime_mois  risque_personnel  loyer_mensuel  \
# 0      73   161.1   67.3                 857              0.11     1377.97000
# 1      44   168.2   74.9                5245              0.79    10000.00000
# 2      71   160.3   45.5                3792              0.13     5000.00000
# 3      62   161.9   87.7                3291              0.32    10000.00000
# 4      18   178.0   77.6                3893              0.66     5175.89104
# ...   ...     ...    ...                 ...               ...            ...
# 9995   37   163.6   96.7                3894              0.63     5000.00000
# 9996   19   157.2   55.3                2969              0.37      787.63000
# 9997   71   163.0   77.2                2893              0.56     1184.94000
# 9998   54   165.7   73.2                1193              0.87     5175.89104
# 9999   54   173.9   77.8                 500              0.70    10000.00000
#
#       montant_pret
# 0     13157.101646
# 1     32408.309272
# 2     17975.461375
# 3     16004.737731
# 4     10437.682760
# ...            ...
# 9995    500.000000
# 9996   7671.982681
# 9997    500.000000
# 9998    500.000000
# 9999   8162.127775
#
# [10000 rows x 7 columns]>
# BOXPLOT : revenu_estime_mois
# UPDATED BOXPLOT : revenu_estime_mois
# BOXPLOT : age
# BOXPLOT : taille
# UPDATED BOXPLOT : taille
# BOXPLOT : poids
# UPDATED BOXPLOT : poids
# BOXPLOT : risque_personnel
# BOXPLOT : loyer_mensuel
# UPDATED BOXPLOT : loyer_mensuel
# BOXPLOT : montant_pret
# UPDATED BOXPLOT : montant_pret
# <bound method NDFrame.describe of       age  taille  poids  revenu_estime_mois  risque_personnel  loyer_mensuel  \
# 2      71   160.3   45.5                3792              0.13     5000.00000
# 4      18   178.0   77.6                3893              0.66     5175.89104
# 5      65   179.5   61.5                2577              0.58     5000.00000
# 8      61   175.2   58.5                1572              0.85     5000.00000
# 11     24   169.1   68.1                3440              0.14     5175.89104
# ...   ...     ...    ...                 ...               ...            ...
# 9989   20   178.7   86.4                2992              0.35     5000.00000
# 9992   34   161.3   69.6                2403              0.11     5175.89104
# 9993   20   167.9   79.2                3066              0.64     5175.89104
# 9995   37   163.6   96.7                3894              0.63     5000.00000
# 9998   54   165.7   73.2                1193              0.87     5175.89104
#
#       montant_pret
# 2     17975.461375
# 4     10437.682760
# 5       500.000000
# 8      4494.300952
# 11    18070.091787
# ...            ...
# 9989  20206.978705
# 9992    500.000000
# 9993    500.000000
# 9995    500.000000
# 9998    500.000000
#
# [5168 rows x 7 columns]>
# /home/thomas/atlas/02 - Exercice/data-cleaner/modules/filter_data.py:113: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /home/thomas/atlas/02 - Exercice/data-cleaner/modules/filter_data.py:119: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ---

# %% [markdown]
# ### Exerice from non RGPD dataset

# %%
import pandas as pd
import missingno as msno

df = pd.read_csv("data/data_not_RGPD.csv")

# %matplotlib inline
msno.matrix(df.sample(250))
# Out:
# <Axes: >

# %%
# %matplotlib inline
msno.bar(df.sample(1000))
# Out:
# <Axes: >

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %% [markdown]
# ### Run script

# %%
# %run modules/anonymise_and_filter_data.py
# Out:
#    age  taille  poids  revenu_estime_mois  risque_personnel  loyer_mensuel  \
# 0   73   161.1   67.3                 857              0.11     1377.97000
# 1   44   168.2   74.9                5245              0.79    10000.00000
# 2   71   160.3   45.5                3792              0.13     5000.00000
# 3   62   161.9   87.7                3291              0.32    10000.00000
# 4   18   178.0   77.6                3893              0.66     5175.89104
#
#    montant_pret  sexe_F  sexe_H  sport_licence_non  ...  \
# 0  13157.101646   False    True               True  ...
# 1  32408.309272   False    True               True  ...
# 2  17975.461375   False    True               True  ...
# 3  16004.737731    True   False              False  ...
# 4  10437.682760    True   False              False  ...
#
#    region_Provence-Alpes-Côte d’Azur  region_Île-de-France  smoker_non  \
# 0                              False                 False        True
# 1                              False                  True        True
# 2                              False                 False       False
# 3                              False                 False       False
# 4                              False                 False        True
#
#    smoker_oui  nationalité_francaise_non  nationalité_francaise_oui  \
# 0       False                      False                       True
# 1       False                      False                       True
# 2        True                      False                       True
# 3        True                      False                       True
# 4       False                      False                       True
#
#    situation_familiale_célibataire  situation_familiale_divorcé  \
# 0                             True                        False
# 1                             True                        False
# 2                             True                        False
# 3                            False                         True
# 4                             True                        False
#
#    situation_familiale_marié  situation_familiale_veuf
# 0                      False                     False
# 1                      False                     False
# 2                      False                     False
# 3                      False                     False
# 4                      False                     False
#
# [5 rows x 32 columns]
# BOXPLOT : revenu_estime_mois
# UPDATED BOXPLOT : revenu_estime_mois
# BOXPLOT : age
# BOXPLOT : taille
# UPDATED BOXPLOT : taille
# BOXPLOT : poids
# UPDATED BOXPLOT : poids
# BOXPLOT : risque_personnel
# BOXPLOT : loyer_mensuel
# UPDATED BOXPLOT : loyer_mensuel
# BOXPLOT : montant_pret
# UPDATED BOXPLOT : montant_pret
# /home/thomas/atlas/02 - Exercice/data-cleaner/modules/anonymise_and_filter_data.py:118: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /home/thomas/atlas/02 - Exercice/data-cleaner/modules/anonymise_and_filter_data.py:124: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
